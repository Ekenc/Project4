# %%
# Initial imports
import pandas as pd
from pathlib import Path
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, mean_absolute_error, mean_squared_error

# %%
# Load the data
url = "https://raw.githubusercontent.com/Ekenc/Project4/main/Data/Merged_Target_Glaciers.csv"
df = pd.read_csv(url)

# Show DataFrame
df.head()
# Out:
#    Unnamed: 0  Year  Mean Nitrous Oxide Concentration  \
# 0           0  1964                             291.2
# 1           1  1967                             291.5
# 2           2  1970                             293.8
# 3           3  1971                             294.0
# 4           4  1972                             295.6
#
#    Mean Carbon Dioxide Concentration  Mean Methane Concentration  \
# 0                         319.620000                     1260.30
# 1                         322.180000                     1284.03
# 2                         325.620315                     1351.70
# 3                         326.320000                     1357.20
# 4                         328.742110                     1380.10
#
#    Mean cumulative mass balance of glaciers  Precipitation Anomaly  \
# 0                                    -2.545              -0.041776
# 1                                    -2.662              -0.096894
# 2                                    -3.519              -0.070516
# 3                                    -3.758               0.032240
# 4                                    -4.016              -0.772485
#
#    Mean Adjusted Sea Level (inches)  Sea Temperature Anomaly  \
# 0                          4.169291                   -0.546
# 1                          4.452756                   -0.420
# 2                          4.677165                   -0.294
# 3                          4.881890                   -0.510
# 4                          5.240157                   -0.186
#
#    Earth Surface Temperature Anomaly (land and ocean)
# 0                                             -0.252
# 1                                              0.000
# 2                                              0.108
# 3                                             -0.126
# 4                                              0.072

# %%
# Define features set
X = df.drop("Mean cumulative mass balance of glaciers", axis = 1)
X = X.drop("Unnamed: 0", axis = 1)
X= X.drop("Precipitation Anomaly", axis = 1)
X.head()
# Out:
#    Year  Mean Nitrous Oxide Concentration  Mean Carbon Dioxide Concentration  \
# 0  1964                             291.2                         319.620000
# 1  1967                             291.5                         322.180000
# 2  1970                             293.8                         325.620315
# 3  1971                             294.0                         326.320000
# 4  1972                             295.6                         328.742110
#
#    Mean Methane Concentration  Mean Adjusted Sea Level (inches)  \
# 0                     1260.30                          4.169291
# 1                     1284.03                          4.452756
# 2                     1351.70                          4.677165
# 3                     1357.20                          4.881890
# 4                     1380.10                          5.240157
#
#    Sea Temperature Anomaly  Earth Surface Temperature Anomaly (land and ocean)
# 0                   -0.546                                             -0.252
# 1                   -0.420                                              0.000
# 2                   -0.294                                              0.108
# 3                   -0.510                                             -0.126
# 4                   -0.186                                              0.072

# %%
# Load the data
url1 = "https://raw.githubusercontent.com/Ekenc/Project4/main/Data/RandomForestRegression_Projected_SeaLevel_Dataframe.csv"
df1 = pd.read_csv(url1)

# Show DataFrame
df1.head()
# Out:
#    Unnamed: 0  Year  Mean Nitrous Oxide Concentration  \
# 0           0  2020                        330.714233
# 1           1  2021                        331.466061
# 2           2  2022                        332.217889
# 3           3  2023                        332.969718
# 4           4  2024                        333.721546
#
#    Mean Carbon Dioxide Concentration  Mean Methane Concentration  \
# 0                         405.576768                 1906.690278
# 1                         407.257998                 1916.355223
# 2                         408.939228                 1926.020169
# 3                         410.620458                 1935.685114
# 4                         412.301688                 1945.350059
#
#    Mean Adjusted Sea Level (inches)  Sea Temperature Anomaly  \
# 0                          9.439804                 0.770041
# 1                          9.449434                 0.792619
# 2                          9.453924                 0.815197
# 3                          9.453924                 0.837775
# 4                          9.453924                 0.860353
#
#    Earth Surface Temperature Anomaly (land and ocean)
# 0                                           1.612599
# 1                                           1.645512
# 2                                           1.678425
# 3                                           1.711339
# 4                                           1.744252

# %%
df1=df1.drop("Unnamed: 0", axis = 1)
df1.head()
# Out:
#    Year  Mean Nitrous Oxide Concentration  Mean Carbon Dioxide Concentration  \
# 0  2020                        330.714233                         405.576768
# 1  2021                        331.466061                         407.257998
# 2  2022                        332.217889                         408.939228
# 3  2023                        332.969718                         410.620458
# 4  2024                        333.721546                         412.301688
#
#    Mean Methane Concentration  Mean Adjusted Sea Level (inches)  \
# 0                 1906.690278                          9.439804
# 1                 1916.355223                          9.449434
# 2                 1926.020169                          9.453924
# 3                 1935.685114                          9.453924
# 4                 1945.350059                          9.453924
#
#    Sea Temperature Anomaly  Earth Surface Temperature Anomaly (land and ocean)
# 0                 0.770041                                           1.612599
# 1                 0.792619                                           1.645512
# 2                 0.815197                                           1.678425
# 3                 0.837775                                           1.711339
# 4                 0.860353                                           1.744252

# %%
# Define target vector
y = df["Mean cumulative mass balance of glaciers"]
y[:48]
# Out:
# 0     -2.545
# 1     -2.662
# 2     -3.519
# 3     -3.758
# 4     -4.016
# 5     -4.147
# 6     -4.339
# 7     -4.534
# 8     -5.140
# 9     -5.919
# 10    -6.726
# 11    -7.009
# 12    -7.586
# 13    -7.475
# 14    -7.559
# 15    -7.892
# 16    -8.399
# 17    -8.832
# 18    -8.935
# 19    -9.242
# 20    -9.917
# 21   -10.384
# 22   -10.819
# 23   -11.611
# 24   -12.134
# 25   -12.861
# 26   -13.088
# 27   -13.317
# 28   -13.755
# 29   -14.326
# 30   -15.018
# 31   -15.758
# 32   -16.591
# 33   -17.202
# 34   -17.619
# 35   -18.169
# 36   -19.011
# 37   -19.920
# 38   -20.657
# 39   -21.502
# 40   -22.285
# 41   -23.402
# 42   -24.383
# 43   -25.152
# 44   -26.043
# 45   -27.174
# Name: Mean cumulative mass balance of glaciers, dtype: float64

# %%
# Splitting into Train and Test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create the StandardScaler instance
scaler = StandardScaler()

# Fit the Standard Scaler with the training data
X_scaler = scaler.fit(X_train)

# %%
# Scale the training data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create the random forest classifier instance
random_model = RandomForestRegressor(n_estimators=100, random_state=78)

# %%
# Fit the model 
random_model = random_model.fit(X_train_scaled, y_train)

# %%
# Making predictions using the testing data
predictions = random_model.predict(X_test_scaled)

# %%
# Calculate the mean squared error, model evaluation
print(
  'mean_squared_error : ', mean_squared_error(y_test, predictions))
print(
  'mean_absolute_error : ', mean_absolute_error(y_test, predictions))
# Out:
# mean_squared_error :  0.1727338820083352
# mean_absolute_error :  0.2851291666666662

# %%
# Compute the model score with training data
random_model.score(X_train_scaled, y_train)
# Out:
# 0.9986740973069917

# %%
# Compute the model score with testing data
random_model.score(X_test_scaled, y_test)
# Out:
# 0.9938245374077398

# %%
#Check Model with Predictions data
Glaciers_Predictions = random_model.predict(df1)
Glaciers_Predictions
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(
# array([-25.97423, -25.95885, -25.95885, -26.03139, -26.05504, -26.05504,
#        -26.05504, -26.05504, -26.05504, -26.05504, -26.21858, -26.21858,
#        -26.21858, -26.21858, -26.21858, -26.21858, -26.21858, -26.30505,
#        -26.30505, -26.30505, -26.30505, -26.30505, -26.38261, -26.38261,
#        -26.40161, -26.40161, -26.40161, -26.36597, -26.36597, -26.36597,
#        -26.36597])

# %%
Glaciers_Predictions_df=df1.copy()
Glaciers_Predictions_df["Mean cumulative mass balance of glaciers"] = Glaciers_Predictions
Glaciers_Predictions_df = Glaciers_Predictions_df[['Year','Mean Nitrous Oxide Concentration', 'Mean Carbon Dioxide Concentration', 'Mean Methane Concentration', 'Mean Adjusted Sea Level (inches)', 'Sea Temperature Anomaly', 'Earth Surface Temperature Anomaly (land and ocean)','Mean cumulative mass balance of glaciers']]
Glaciers_Predictions_df
# Out:
#     Year  Mean Nitrous Oxide Concentration  Mean Carbon Dioxide Concentration  \
# 0   2020                        330.714233                         405.576768
# 1   2021                        331.466061                         407.257998
# 2   2022                        332.217889                         408.939228
# 3   2023                        332.969718                         410.620458
# 4   2024                        333.721546                         412.301688
# 5   2025                        334.473374                         413.982918
# 6   2026                        335.225202                         415.664148
# 7   2027                        335.977030                         417.345378
# 8   2028                        336.728858                         419.026608
# 9   2029                        337.480687                         420.707838
# 10  2030                        338.232515                         422.389068
# 11  2031                        338.984343                         424.070298
# 12  2032                        339.736171                         425.751528
# 13  2033                        340.487999                         427.432758
# 14  2034                        341.239828                         429.113988
# 15  2035                        341.991656                         430.795218
# 16  2036                        342.743484                         432.476448
# 17  2037                        343.495312                         434.157678
# 18  2038                        344.247140                         435.838908
# 19  2039                        344.998968                         437.520138
# 20  2040                        345.750797                         439.201368
# 21  2041                        346.502625                         440.882598
# 22  2042                        347.254453                         442.563828
# 23  2043                        348.006281                         444.245058
# 24  2044                        348.758109                         445.926288
# 25  2045                        349.509938                         447.607518
# 26  2046                        350.261766                         449.288748
# 27  2047                        351.013594                         450.969978
# 28  2048                        351.765422                         452.651208
# 29  2049                        352.517250                         454.332438
# 30  2050                        353.269078                         456.013668
#
#     Mean Methane Concentration  Mean Adjusted Sea Level (inches)  \
# 0                  1906.690278                          9.439804
# 1                  1916.355223                          9.449434
# 2                  1926.020169                          9.453924
# 3                  1935.685114                          9.453924
# 4                  1945.350059                          9.453924
# 5                  1955.015005                          9.453924
# 6                  1964.679950                          9.453924
# 7                  1974.344895                          9.453924
# 8                  1984.009840                          9.453924
# 9                  1993.674786                          9.453924
# 10                 2003.339731                          9.453924
# 11                 2013.004676                          9.453924
# 12                 2022.669622                          9.453924
# 13                 2032.334567                          9.453924
# 14                 2041.999512                          9.453924
# 15                 2051.664457                          9.453924
# 16                 2061.329403                          9.453924
# 17                 2070.994348                          9.453924
# 18                 2080.659293                          9.453924
# 19                 2090.324239                          9.471948
# 20                 2099.989184                          9.471948
# 21                 2109.654129                          9.471948
# 22                 2119.319074                          9.471948
# 23                 2128.984020                          9.471948
# 24                 2138.648965                          9.489971
# 25                 2148.313910                          9.489971
# 26                 2157.978856                          9.489971
# 27                 2167.643801                          9.489971
# 28                 2177.308746                          9.489971
# 29                 2186.973691                          9.489971
# 30                 2196.638637                          9.504290
#
#     Sea Temperature Anomaly  \
# 0                  0.770041
# 1                  0.792619
# 2                  0.815197
# 3                  0.837775
# 4                  0.860353
# 5                  0.882931
# 6                  0.905509
# 7                  0.928088
# 8                  0.950666
# 9                  0.973244
# 10                 0.995822
# 11                 1.018400
# 12                 1.040978
# 13                 1.063556
# 14                 1.086134
# 15                 1.108713
# 16                 1.131291
# 17                 1.153869
# 18                 1.176447
# 19                 1.199025
# 20                 1.221603
# 21                 1.244181
# 22                 1.266759
# 23                 1.289338
# 24                 1.311916
# 25                 1.334494
# 26                 1.357072
# 27                 1.379650
# 28                 1.402228
# 29                 1.424806
# 30                 1.447384
#
#     Earth Surface Temperature Anomaly (land and ocean)  \
# 0                                            1.612599
# 1                                            1.645512
# 2                                            1.678425
# 3                                            1.711339
# 4                                            1.744252
# 5                                            1.777165
# 6                                            1.810079
# 7                                            1.842992
# 8                                            1.875905
# 9                                            1.908819
# 10                                           1.941732
# 11                                           1.974645
# 12                                           2.007558
# 13                                           2.040472
# 14                                           2.073385
# 15                                           2.106298
# 16                                           2.139212
# 17                                           2.172125
# 18                                           2.205038
# 19                                           2.237952
# 20                                           2.270865
# 21                                           2.303778
# 22                                           2.336691
# 23                                           2.369605
# 24                                           2.402518
# 25                                           2.435431
# 26                                           2.468345
# 27                                           2.501258
# 28                                           2.534171
# 29                                           2.567085
# 30                                           2.599998
#
#     Mean cumulative mass balance of glaciers
# 0                                  -25.97423
# 1                                  -25.95885
# 2                                  -25.95885
# 3                                  -26.03139
# 4                                  -26.05504
# 5                                  -26.05504
# 6                                  -26.05504
# 7                                  -26.05504
# 8                                  -26.05504
# 9                                  -26.05504
# 10                                 -26.21858
# 11                                 -26.21858
# 12                                 -26.21858
# 13                                 -26.21858
# 14                                 -26.21858
# 15                                 -26.21858
# 16                                 -26.21858
# 17                                 -26.30505
# 18                                 -26.30505
# 19                                 -26.30505
# 20                                 -26.30505
# 21                                 -26.30505
# 22                                 -26.38261
# 23                                 -26.38261
# 24                                 -26.40161
# 25                                 -26.40161
# 26                                 -26.40161
# 27                                 -26.36597
# 28                                 -26.36597
# 29                                 -26.36597
# 30                                 -26.36597

# %%
from google.colab import files
Glaciers_Predictions_df.to_csv("RandomForestRegression_Glacier_Dataframe.csv",encoding = 'utf-8-sig')
files.download('RandomForestRegression_Glacier_Dataframe.csv')
